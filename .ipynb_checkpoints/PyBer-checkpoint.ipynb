# %%
#magic command
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
# used path but would like to use os for this
city_data_to_load = "resources\city_data.csv"
ride_data_to_load = os.path.join("resources", "ride_data.csv")
print(ride_data_to_load)
# Out:
# resources\ride_data.csv

# %%
#read the csv files into pandas
city_data_df = pd.read_csv(city_data_to_load)
city_data_df.head(10)
# Out:
#             city  driver_count   type
# 0    Richardfort            38  Urban
# 1   Williamsstad            59  Urban
# 2    Port Angela            67  Urban
# 3     Rodneyfort            34  Urban
# 4    West Robert            39  Urban
# 5   West Anthony            70  Urban
# 6    West Angela            48  Urban
# 7  Martinezhaven            25  Urban
# 8      Karenberg            22  Urban
# 9    Barajasview            26  Urban

# %%
ride_data_df = pd.read_csv(ride_data_to_load)
ride_data_df.head(10)
# Out:
#                  city             date   fare       ride_id
# 0  Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12
# 1  South Michelleport   3/4/2019 18:24  30.24  2.343910e+12
# 2  Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12
# 3          Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12
# 4          South Jack    3/6/2019 4:28  34.58  3.908450e+12
# 5        South Latoya  3/11/2019 12:26   9.52  1.995000e+12
# 6       New Paulville  2/27/2019 11:17  43.25  7.932080e+11
# 7        Simpsonburgh   4/26/2019 0:43  35.98  1.119540e+11
# 8     South Karenland    1/8/2019 3:28  35.09  7.995620e+12
# 9       North Jasmine    3/9/2019 6:26  42.81  5.327640e+12

# %%
#checking data quality by shecking for null values and summing them. 
ride_data_df.isnull().sum()
# Out:
# city       0
# date       0
# fare       0
# ride_id    0
# dtype: int64

# %%
#checking data quality
city_data_df.isnull().sum()
# Out:
# city            0
# driver_count    0
# type            0
# dtype: int64

# %%
#Checking data types
ride_data_df.dtypes
# Out:
# city        object
# date        object
# fare       float64
# ride_id    float64
# dtype: object

# %%
city_data_df.dtypes
# Out:
# city            object
# driver_count     int64
# type            object
# dtype: object

# %%
city_data_df["type"].unique()
# Out:
# array(['Urban', 'Suburban', 'Rural'], dtype=object)

# %%
u = sum(city_data_df["type"] == "Urban")
r = sum(city_data_df["type"] == "Rural")
s = sum(city_data_df["type"] == "Suburban")
print(u,r,s)
# Out:
# 66 18 36

# %%
 ride_data_df.count()
# Out:
# city       2375
# date       2375
# fare       2375
# ride_id    2375
# dtype: int64

# %%
ride_data_df.dtypes
# Out:
# city        object
# date        object
# fare       float64
# ride_id    float64
# dtype: object

# %%
ride_data_df.isnull().sum()
# Out:
# city       0
# date       0
# fare       0
# ride_id    0
# dtype: int64

# %%
city_data_df
# Out:
#                 city  driver_count   type
# 0        Richardfort            38  Urban
# 1       Williamsstad            59  Urban
# 2        Port Angela            67  Urban
# 3         Rodneyfort            34  Urban
# 4        West Robert            39  Urban
# ..               ...           ...    ...
# 115     Bradshawfurt             7  Rural
# 116     New Ryantown             2  Rural
# 117   Randallchester             9  Rural
# 118      Jessicaport             1  Rural
# 119  South Saramouth             7  Rural
#
# [120 rows x 3 columns]

# %%
ride_data_df
# Out:
#                     city             date   fare       ride_id
# 0     Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12
# 1     South Michelleport   3/4/2019 18:24  30.24  2.343910e+12
# 2     Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12
# 3             Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12
# 4             South Jack    3/6/2019 4:28  34.58  3.908450e+12
# ...                  ...              ...    ...           ...
# 2370         Michaelberg  4/29/2019 17:04  13.38  8.550370e+12
# 2371     Lake Latoyabury   1/30/2019 0:05  20.76  9.018730e+12
# 2372         North Jaime  2/10/2019 21:03  11.11  2.781340e+12
# 2373        West Heather   5/7/2019 19:22  44.94  4.256850e+12
# 2374          Newtonview  4/25/2019 10:20  55.84  9.990580e+12
#
# [2375 rows x 4 columns]

# %%
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city"])
pyber_data_df.head()
#pyber_data_df.dtypes
# Out:
#                  city             date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12             5
# 1  South Michelleport   3/4/2019 18:24  30.24  2.343910e+12            72
# 2  Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12            57
# 3          Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12            34
# 4          South Jack    3/6/2019 4:28  34.58  3.908450e+12            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %%
#create a df that is specific for each type
urban_cities_df = pyber_data_df[pyber_data_df["type"] =="Urban"]
suburban_cities_df = pyber_data_df[pyber_data_df["type"] == "Suburban"]
rural_cities_df = pyber_data_df[pyber_data_df["type"] == "Rural"]
print(urban_cities_df,suburban_cities_df, rural_cities_df)
# Out:
#                     city             date   fare       ride_id  driver_count  \
# 0     Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12             5
# 1     South Michelleport   3/4/2019 18:24  30.24  2.343910e+12            72
# 2     Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12            57
# 3             Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12            34
# 4             South Jack    3/6/2019 4:28  34.58  3.908450e+12            46
# ...                  ...              ...    ...           ...           ...
# 1620        Reynoldsfurt  2/14/2019 11:25  39.40  9.070690e+12            67
# 1621     Christopherfurt   3/13/2019 1:47  32.05  2.788820e+12            41
# 1622        Raymondhaven   3/20/2019 2:20  38.53  8.658260e+12            11
# 1623       Port Johnbury   3/26/2019 7:22   7.63  8.089280e+12             3
# 1624        West Gabriel    5/5/2019 1:24  27.57  4.428770e+12            57
#
#        type
# 0     Urban
# 1     Urban
# ...

# %%
#get the number of rides for the urban cities
urban_ride_count = urban_cities_df.groupby(["city"]).count()["ride_id"]
urban_ride_count
# Out:
# city
# Amandaburgh            18
# Barajasview            22
# Carriemouth            27
# Christopherfurt        27
# Deanville              19
#                        ..
# West Patrickchester    16
# West Robert            31
# West Samuelburgh       25
# Williamsstad           23
# Williamsview           20
# Name: ride_id, Length: 66, dtype: int64

# %%
# Create the suburban and rural ride count.
suburban_ride_count = suburban_cities_df.groupby(["city"]).count()["ride_id"]

rural_ride_count = rural_cities_df.groupby(["city"]).count()["ride_id"]

# %%
#get the avg fare for each of the cities using groupby()
urban_avg_fare = urban_cities_df.groupby(["city"]).mean()["fare"]
suburban_avg_fare = suburban_cities_df.groupby(["city"]).mean()["fare"]
rural_avg_fare = rural_cities_df.groupby(["city"]).mean()["fare"]
print(urban_avg_fare, suburban_avg_fare, rural_avg_fare)
# Out:
# city
# Amandaburgh            24.641667
# Barajasview            25.332273
# Carriemouth            28.314444
# Christopherfurt        24.501852
# Deanville              25.842632
#                          ...
# West Patrickchester    28.233125
# West Robert            25.123871
# West Samuelburgh       21.767600
# Williamsstad           24.362174
# Williamsview           26.599000
# Name: fare, Length: 66, dtype: float64 city
# Barronchester         36.422500
# Bethanyland           32.956111
# Brandonfort           35.437368
# Colemanland           30.894545
# Davidfurt             31.995882
# East Aaronbury        25.661111
# East Danielview       31.560588
# East Kentstad         29.823077
# East Marymouth        30.835185
# Grayville             27.763333
# Josephside            32.858148
# Lake Ann              30.890000
# Lake Omar             28.075000
# Lake Robertside       31.262000
# Lake Scott            31.886111
# Lewishaven            25.241667
# ...

# %%
# Get the average number of drivers for each urban city.
urban_driver_count = urban_cities_df.groupby(["city"]).mean()["driver_count"]
# Get the average number of drivers for each city for the suburban and rural cities.
suburban_driver_count = suburban_cities_df.groupby(["city"]).mean()["driver_count"]
rural_driver_count = rural_cities_df.groupby(["city"]).mean()["driver_count"]
print(urban_driver_count.head(), suburban_driver_count.head(), rural_driver_count.head())
# Out:
# city
# Amandaburgh        12
# Barajasview        26
# Carriemouth        52
# Christopherfurt    41
# Deanville          49
# Name: driver_count, dtype: int64 city
# Barronchester    11
# Bethanyland      22
# Brandonfort      10
# Colemanland      23
# Davidfurt        23
# Name: driver_count, dtype: int64 city
# Bradshawfurt      7
# Garzaport         7
# Harringtonfort    4
# Jessicaport       1
# Lake Jamie        4
# Name: driver_count, dtype: int64

# %%
#build a scatter plot using urban data
plt.scatter(urban_ride_count, 
            urban_avg_fare, 
            s=10*urban_driver_count,
            c="coral", edgecolor="black",
            linewidths=1, alpha=0.8, label="Urban")
plt.title=("Pyber Ride-Sharing Data (2021)")
plt.ylabel=("Avg Fare ($)")
plt.xlabel=("Total Number of Rides (PerCity)")
plt.legend()
plt.grid=True

# %%
#build a scatter plot using urban data
plt.scatter(suburban_ride_count, 
            suburban_avg_fare, 
            s=10*suburban_driver_count,
            c="skyblue", edgecolor="black",
            linewidths=1, alpha=0.8, label="Suburban")
plt.title=("Pyber Ride-Sharing Data (2021)")
plt.ylabel=("Avg Fare ($)")
plt.xlabel=("Total Number of Rides (PerCity)")
plt.legend()
plt.grid=True

# %%
#build a scatter plot using urban data
plt.scatter(rural_ride_count, 
            rural_avg_fare, 
            s=10*rural_driver_count,
            c="gold", edgecolor="black",
            linewidths=1, alpha=0.8, label="Rural")
plt.title=("Pyber Ride-Sharing Data (2021)")
plt.ylabel=("Avg Fare ($)")
plt.xlabel=("Total Number of Rides (PerCity)")
plt.legend()
plt.grid=True

# %%
# Add the scatter charts for each type of city.
plt.scatter(urban_ride_count,
      urban_avg_fare,
      s=10*urban_driver_count, c="coral",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Urban")

plt.scatter(suburban_ride_count,
      suburban_avg_fare,
      s=10*suburban_driver_count, c="skyblue",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Suburban")

plt.scatter(rural_ride_count,
      rural_avg_fare,
      s=10*rural_driver_count, c="gold",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="Rural")

plt.title=("Pyber Ride-Sharing Data (2021)")
plt.ylabel=("Avg Fare ($)")
plt.xlabel=("Total Number of Rides (PerCity)")
#using just legend makes the legend size markers based on the average
#plt.legend()
plt.grid=True


# Create a legend
lgnd = plt.legend(fontsize="12", mode="Expanded",
         scatterpoints=1, loc="best", title="City Types")
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]
lgnd.get_title().set_fontsize(12)

# Incorporate a text label about circle size.
plt.text(42, 35, "Note: Circle size correlates with driver count per city.", fontsize="12")

#save the figure
plt.savefig("fig1.png")
# Show the plot
plt.show()

# %%
#get Summary statistics
print(urban_cities_df.describe(), suburban_cities_df.describe(), rural_cities_df.describe())
# Out:
#               fare       ride_id  driver_count
# count  1625.000000  1.625000e+03   1625.000000
# mean     24.525772  4.873485e+12     36.678154
# std      11.738649  2.907440e+12     20.075545
# min       4.050000  1.458810e+10      3.000000
# 25%      14.550000  2.400240e+12     22.000000
# 50%      24.640000  4.711190e+12     37.000000
# 75%      34.580000  7.451580e+12     52.000000
# max      44.970000  9.991540e+12     73.000000              fare       ride_id  driver_count
# count  625.000000  6.250000e+02    625.000000
# mean    30.970128  4.971015e+12     13.712000
# std     10.677508  2.912410e+12      8.042372
# min     12.050000  3.218337e+08      1.000000
# 25%     21.970000  2.364250e+12      5.000000
# 50%     30.750000  5.053220e+12     16.000000
# 75%     39.830000  7.551670e+12     21.000000
# max     49.960000  9.917740e+12     25.000000              fare       ride_id  driver_count
# count  125.000000  1.250000e+02    125.000000
# ...

# %%
urban_ride_count.describe()
# Out:
# count    66.000000
# mean     24.621212
# std       5.408726
# min      12.000000
# 25%      21.000000
# 50%      24.000000
# 75%      28.000000
# max      39.000000
# Name: ride_id, dtype: float64

# %%
suburban_ride_count.describe()
# Out:
# count    36.000000
# mean     17.361111
# std       4.323707
# min       9.000000
# 25%      14.000000
# 50%      17.000000
# 75%      19.250000
# max      27.000000
# Name: ride_id, dtype: float64

# %%
rural_ride_count.describe()
# Out:
# count    18.000000
# mean      6.944444
# std       2.508157
# min       3.000000
# 25%       5.250000
# 50%       6.000000
# 75%       8.750000
# max      12.000000
# Name: ride_id, dtype: float64

# %%
# Calculate the mean of the ride count for each city type.
round(urban_ride_count.mean(),2), round(suburban_ride_count.mean(),2), round(rural_ride_count.mean(),2)
# Out:
# (24.62, 17.36, 6.94)

# %%
# Calculate the median of the ride count for each city type.
round(urban_ride_count.median(),2), round(suburban_ride_count.median(),2), round(rural_ride_count.median(),2)
# Out:
# (24.0, 17.0, 6.0)

# %%
urban_ride_count.mode(), suburban_ride_count.mode(),rural_ride_count.mode()
# Out:
# (0    22
#  1    25
#  dtype: int64,
#  0    17
#  dtype: int64,
#  0    6
#  dtype: int64)

# %%
# Import NumPy and the stats module from SciPy.
import numpy as np
import scipy.stats as sts

# %%
# Calculate the measures of central tendency for the ride count for the urban cities.
mean_urban_ride_count = np.mean(urban_ride_count)
print(f"The mean for the ride counts for the urban trips is {mean_urban_ride_count:.2f}")

median_urban_ride_count = np.median(urban_ride_count)
print(f"The median for the ride counts for urban trips is {median_urban_ride_count}.")

mode_urban_ride_count = sts.mode(urban_ride_count)
print(f"The mode for the ride counts for urban trips is {mode_urban_ride_count}.")
# Out:
# The mean for the ride counts for the urban trips is 24.62
# The median for the ride counts for urban trips is 24.0.
# The mode for the ride counts for urban trips is ModeResult(mode=array([22], dtype=int64), count=array([7])).

# %%
# Calculate the measures of central tendency for the ride count for the urban cities.
mean_suburban_ride_count = np.mean(suburban_ride_count)
print(f"The mean for the ride counts for the auburban trips is {mean_suburban_ride_count:.2f}")

median_suburban_ride_count = np.median(suburban_ride_count)
print(f"The median for the ride counts for suburban trips is {median_suburban_ride_count}.")

mode_suburban_ride_count = sts.mode(suburban_ride_count)
print(f"The mode for the ride counts for auburban trips is {mode_suburban_ride_count}.")
# Out:
# The mean for the ride counts for the auburban trips is 17.36
# The median for the ride counts for suburban trips is 17.0.
# The mode for the ride counts for auburban trips is ModeResult(mode=array([17], dtype=int64), count=array([7])).

# %%
# Calculate the measures of central tendency for the ride count for the urban cities.
mean_rural_ride_count = np.mean(rural_ride_count)
print(f"The mean for the ride counts for the rural trips is {mean_rural_ride_count:.2f}")

median_rural_ride_count = np.median(rural_ride_count)
print(f"The median for the ride counts for suburban trips is {median_rural_ride_count}.")

mode_rural_ride_count = sts.mode(rural_ride_count)
print(f"The mode for the ride counts for rural trips is {mode_rural_ride_count}.")
# Out:
# The mean for the ride counts for the rural trips is 6.94
# The median for the ride counts for suburban trips is 6.0.
# The mode for the ride counts for rural trips is ModeResult(mode=array([6], dtype=int64), count=array([5])).

# %%
#get the fares for the urban cities
urban_fare = urban_cities_df["fare"]
suburban_fare = suburban_cities_df["fare"]
rural_fare = rural_cities_df["fare"]
#print(urban_fare)

# %%
# Calculate the measures of central tendency for the average fare for the urban cities.
mean_urban_fare = np.mean(urban_fare)
print(f"The mean for urban is ${mean_urban_fare:.2f}")

median_urban_fare = np.median(urban_fare)
print(f"The medain for urban is ${median_urban_fare:.2f}")
mode_urban_fare = sts.mode(urban_fare)
print(f"The mode for urban is ${mode_urban_fare}")
# Out:
# The mean for urban is $24.53
# The medain for urban is $24.64
# The mode for urban is $ModeResult(mode=array([22.86]), count=array([5]))

# %%
# Calculate the measures of central tendency for the average fare for the suburban cities.
mean_suburban_fare = np.mean(suburban_fare)
print(f"The mean for suburban is ${mean_suburban_fare:.2f}")

median_suburban_fare = np.median(suburban_fare)
print(f"The medain for suburban is ${median_suburban_fare:.2f}")
mode_suburban_fare = sts.mode(suburban_fare)
print(f"The mode for suburban is ${mode_suburban_fare}")
# Out:
# The mean for suburban is $30.97
# The medain for suburban is $30.75
# The mode for suburban is $ModeResult(mode=array([17.99]), count=array([3]))

# %%
# Calculate the measures of central tendency for the average fare for the rural cities.
mean_rural_fare = np.mean(rural_fare)
print(f"The mean for rural is ${mean_rural_fare:.2f}")

median_rural_fare = np.median(rural_fare)
print(f"The medain for rural is ${median_rural_fare:.2f}")
mode_rural_fare = sts.mode(rural_fare)
print(f"The mode for rural is ${mode_rural_fare}")
# Out:
# The mean for rural is $34.62
# The medain for rural is $37.05
# The mode for rural is $ModeResult(mode=array([37.05]), count=array([2]))

# %%
# Get the driver count data from the urban cities.  then I added for each city
urban_drivers = urban_cities_df["driver_count"]
suburban_drivers = suburban_cities_df["driver_count"]
rural_drivers = rural_cities_df["driver_count"]

# %%
#calculate the mean, median, mode for driver count for each city type
mean_urban_driver = np.mean(urban_drivers)
mean_suburban_driver = np.mean(suburban_drivers)
mean_rural_driver = np.mean(rural_drivers)
print(mean_urban_driver, mean_suburban_driver, mean_rural_driver)
# Out:
# 36.67815384615385 13.712 4.296

# %%
# Create a box-and-whisker plot for the urban cities ride count.
x_labels = ["Urban"]
fig, ax = plt.subplots(figsize=(10,10))
ax.boxplot(urban_ride_count, labels=x_labels)

#add the title , y axis, and lable and grid

ax.set_title('Ride Count Data (2019)')
ax.set_ylabel('Number of Rides')
ax.set_yticks(np.arange(10, 41, step=2.0))
ax.grid()
plt.show()

# %%
# Create a box-and-whisker plot for the urban cities ride count.
x_labels = ["Suburban"]
fig, ax = plt.subplots(figsize=(10,10))
ax.boxplot(suburban_ride_count, labels=x_labels)

#add the title , y axis, and lable and grid

ax.set_title('Suburban Ride Count Data (2019)')
ax.set_ylabel('Number of Rides')
ax.set_yticks(np.arange(8, 30, step=2.0))
ax.grid()
plt.show()

# %%
# Create a box-and-whisker plot for the urban cities ride count.
x_labels = ["Rural"]
fig, ax = plt.subplots(figsize=(10,10))
ax.boxplot(rural_ride_count, labels=x_labels)

#add the title , y axis, and lable and grid

ax.set_title('Rural Ride Count Data (2019)')
ax.set_ylabel('Number of Rides')
ax.set_yticks(np.arange(2, 14, step=2.0))
ax.grid()
plt.show()

# %%
# Add all ride count box-and-whisker plots to the same graph.
x_labels = ["Urban", "Suburban","Rural"]
ride_count_data = [urban_ride_count, suburban_ride_count, rural_ride_count]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Ride Count Data (2019)',fontsize=20)
ax.set_ylabel('Number of Rides',fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(ride_count_data, labels=x_labels)
ax.set_yticks(np.arange(0, 45, step=3.0))
ax.grid()
# Save the figure.
plt.savefig("analysis/Fig2.png")
plt.show()

# %%
# Get the city that matches 39.
urban_city_outlier = urban_ride_count[urban_ride_count==39].index[0]
print(f"{urban_city_outlier} has the highest rider count.")
# Out:
# West Angela has the highest rider count.

# %%
# Create a box-and-whisker plot for the urban fare data.
x_labels = ["Urban"]
fig, ax = plt.subplots(figsize=(10,10))
ax.boxplot(urban_fare, labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Ride Fare Data (2019)')
ax.set_ylabel('Fare($USD)')
ax.set_yticks(np.arange(0, 51, step=5.0))
ax.grid()
plt.show()
print("Summary Statistics")
urban_fare.describe()
# Out:
# Summary Statistics
# count    1625.000000
# mean       24.525772
# std        11.738649
# min         4.050000
# 25%        14.550000
# 50%        24.640000
# 75%        34.580000
# max        44.970000
# Name: fare, dtype: float64

# %%
# Add all ride count box-and-whisker plots to the same graph.
x_labels = ["Urban", "Suburban","Rural"]
ride_count_data = [urban_fare, suburban_fare, rural_fare]
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_title('Ride Fare Data (2019)',fontsize=20)
ax.set_ylabel('Number of Rides',fontsize=14)
ax.set_xlabel("City Types",fontsize=14)
ax.boxplot(ride_count_data, labels=x_labels)
ax.set_yticks(np.arange(0, 60, step=5.0))
ax.grid()
# Save the figure.
plt.savefig("analysis/Fig3.png")
plt.show()

# %%
# Create the box-and-whisker plot for the urban driver count data.
x_labels = ["Urban" , "Suburban" , "Rural"]
fig, ax = plt.subplots(figsize=(10,10))
driver_count_data = [urban_drivers, suburban_drivers, rural_drivers]
ax.boxplot(driver_count_data,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Driver Count Data (2019)')
ax.set_ylabel('Number of Drivers)')
ax.set_yticks(np.arange(0, 80, step=5.0))
ax.grid()
# Save the figure.
plt.savefig("analysis/Fig4.png")
plt.show()

# %%
# Create the box-and-whisker plot for the urban driver count data.
x_labels = ["Urban"]
fig, ax = plt.subplots()
ax.boxplot(urban_drivers,labels=x_labels)
# Add the title, y-axis label and grid.
ax.set_title('Driver Count Data (2019)')
ax.set_ylabel('Number of Drivers)')
ax.set_yticks(np.arange(0, 90, step=5.0))
ax.grid()
plt.show()
print("Summary Statistics")
urban_drivers.describe()
# Out:
# Summary Statistics
# count    1625.000000
# mean       36.678154
# std        20.075545
# min         3.000000
# 25%        22.000000
# 50%        37.000000
# 75%        52.000000
# max        73.000000
# Name: driver_count, dtype: float64

# %%
# get the sum of the fares for each city
sum_fares_by_type = pyber_data_df.groupby(["type"]).sum()["fare"]
sum_fares_by_type
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
# Get the sum of all the fares.
total_fare = pyber_data_df["fare"].sum()
total_fare
# Out:
# 63538.64

# %%
# Calculate the percentage of fare for each city type.
type_percents = sum_fares_by_type / total_fare * 100
type_percents
# Out:
# type
# Rural        6.811493
# Suburban    30.463872
# Urban       62.724635
# Name: fare, dtype: float64

# %%
# Build the percentage of fares by city type pie chart.


# plt.title(label = "Total Fares by City Type", loc="left")

import matplotlib.pyplot as plt
from importlib import reload

plt = reload(plt)
# fig = plt.figure()
plt.title("SampleChart")
plt.pie(type_percents,
    labels=["Rural", "Suburban", "Urban"],
    colors=["gold", "lightskyblue", "lightcoral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)



# Show Figure
plt.show()

# %%
# Import mpl to change the plot configurations using rcParams.
import matplotlib as mpl
# Build Pie Chart
#fig, ax = subplots()
plt.pie(type_percents,
    labels=["Rural", "Suburban", "Urban"],
    colors=["gold", "lightskyblue", "lightcoral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)
plt.title("% of Total Fares by City Type")

# Change the default font size from 10 to 14.
mpl.rcParams['font.size'] = 14
# Save Figure
plt.savefig("analysis/Fig5.png")
# Show Figure
plt.show()

# %%
# percent of rides by city type, this time calling the data and doing the math
ride_percent = pyber_data_df.groupby(["type"]).count()["ride_id"] / pyber_data_df["ride_id"].count() * 100
ride_percent
# Out:
# type
# Rural        5.263158
# Suburban    26.315789
# Urban       68.421053
# Name: ride_id, dtype: float64

# %%
# Build Pie Chart for recent of rides by city
plt.subplots(figsize=(10, 10))
plt.pie(ride_percent,
    labels=["Rural", "Suburban", "Urban"],
    colors=["Blue", "skyblue", "coral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)
plt.title("Percent of Rides by City Type")
# Change the default font size from 10 to 14.
mpl.rcParams['font.size'] = 14
# Save Figure
plt.savefig("analysis/Fig6.png")
# Show Figure
plt.show()

# %%
# get the percent of drivers by city type

driver_percent = pyber_data_df.groupby(["type"]).sum()["driver_count"] / pyber_data_df["driver_count"].sum() * 100
#driver_percent
percent_drivers = city_data_df.groupby(["type"]).sum()["driver_count"] / city_data_df["driver_count"].sum() * 100
print(driver_percent, percent_drivers)
# Out:
# type
# Rural        0.781557
# Suburban    12.472893
# Urban       86.745550
# Name: driver_count, dtype: float64 type
# Rural        2.623613
# Suburban    16.481668
# Urban       80.894719
# Name: driver_count, dtype: float64

# %%
pyber_data_df.head()
# Out:
#                  city             date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12             5
# 1  South Michelleport   3/4/2019 18:24  30.24  2.343910e+12            72
# 2  Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12            57
# 3          Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12            34
# 4          South Jack    3/6/2019 4:28  34.58  3.908450e+12            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %%
# Build Pie Chart for recent of driver by city
plt.subplots(figsize=(10, 10))
plt.pie(percent_drivers,
    labels=["Rural", "Suburban", "Urban"],
    colors=["Blue", "skyblue", "coral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)
plt.title("Percent of Rides by City Type")
# Change the default font size from 10 to 14.
mpl.rcParams['font.size'] = 20
# Save Figure
plt.savefig("analysis/Fig7.png")
# Show Figure
plt.show()

# %%
# Build Pie Chart for recent of driver by city
plt.subplots(figsize=(10, 10))
plt.pie(percent_drivers,
    labels=["Rural", "Suburban", "Urban"],
    colors=["Blue", "skyblue", "coral"],
    explode=[0, 0, 0.1],
    autopct='%1.1f%%',
    shadow=True, startangle=150)
plt.title("Percent of Rides by City Type")
# Change the default font size from 10 to 14.
mpl.rcParams['font.size'] = 10
# Save Figure
plt.savefig("analysis/Fig7.png")
# Show Figure
plt.show()
